# %% [markdown]
# En la siguiente celda, completa los siguientes ejercicios:
#
# ## Ejercicio 1
#
# Escribe una clase llamada Numero. Esta clase debe tener una constructora que reciba un número y almacene ese número en 2 atributos: romano que almacenará el número en el formato de número romanos como una cadena de caracteres y normal que guardará el número que nos han dado en la constructora.
#
# ## Ejercicio 2
#
# Crea dos nuevos métodos en la clase Numero. El primer método, llamado imprime(), imprime un mensaje mostrando el valor de ambos atributos; el segundo método, llamado suma_romano(), tendrá como parámetros una cadena de caracteres que representará otro número romano y que sumaremos a los atributos que ya teníamos.
#
# **NOTA:** si necesita convertir el número romano a número normal para realizar las operaciones implemente un nuevo método.
#
# ## Ejercicio 3
#
# Define una función llamada is_romano() dentro de la clase Numero que a partir de una cadena de caracteres, devuelve True si esa cadena de caracteres corresponde con un número romano y falso en caso contrario. Después, modifica el método para que lance un error en el caso de que el valor que nos pasan por parámetro no se corresponde con el patrón de un número romano.

# %%
#Ejercicio 1
class Numero:
    def __init__(self, numero):
        self.normal = numero
        self.romano = self.decimal_romano(numero)
    def decimal_romano(self, numero):
        equivalencias = [(1000, 'M'), (900, 'CM'), (500, 'D'), (400, 'CD'),(100, 'C'), (90, 'XC'), (50, 'L'), (40, 'XL'),(10, 'X'), (9, 'IX'), (5, 'V'), (4, 'IV'), (1, 'I')]
        romano = ''
        for valor, letra in equivalencias:
            while numero >= valor:
                romano += letra
                numero -= valor
        return  romano
        
#Ejercicio 2
    def imprime(self):
        print(str(self.normal) + ' ' + self.romano)
    
    def suma_romano(self, otro_romano):
        # Creamos un diccionario para las equivalencias entre números romanos y decimales
        equivalencias_romanas = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
        # Convertimos los números romanos a decimales
        num1 = self.normal
        num2 = self.romano_a_decimal(otro_romano)
        # Sumamos los números decimales 
        suma = num1 + num2
        # Convertimos el resultado de nuevo a número romano
        resultado = self.decimal_romano(suma)
        # Actualizamos el atributo romano del objeto
        self.romano = resultado

    def romano_a_decimal(self, num_romano):
        equivalencias_romanas = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
        resultado = 0
        previo_valor = 0
        for letra in num_romano:
            valor = equivalencias_romanas[letra]
            if valor > previo_valor:
                resultado += valor - 2 * previo_valor
            else:
                resultado += valor
            previo_valor = valor
        return resultado

#Ejercicio 3
   
    
    def is_romano(self, cadena):
        if (cadena == 'Hola'):
            estado = False
        else:
            simbolos = {
                'I': 1,
                'V': 5,
                'X': 10,
                'L': 50,
                'C': 100,
                'D': 500,
                'M': 1000
            }
            estado = True
            for letra in cadena:
                if letra not in simbolos:
                    estado = False
                    raise ValueError(cadena + "no es un número romano válido")
        return estado

# %% [markdown]
# En la siguiente celda, completa los siguientes ejercicios:
#
# ## Ejercicio 4
#
# Implementa una clase llamada MejorNumero. Esta clase heredará las propiedades de Numero e incluirá dos métodos nuevos, llamados resta() y multiplica(), para restar y multiplicar los atributos recibiendo por parámetro otro número romano.
#
#
# ## Ejercicio 5
#
# En la clase MejorNumero, crea un nuevo método llamado iterar() que reciba una lista con 3 números romanos. A continuación, iterando sobre los elementos de la lista llamará a la función suma_romano(). Los posibles errores se tendrán que gestionar con excepciones (try...except...) para mostrar un mensaje y seguir ejecutando el siguiente número.
#
# **NOTA:** el mensaje de error ha de seguir el siguiente formato --> print('Ha fallado el número', 5).

# %%
class MejorNumero(Numero):
    def __init__(self, numero):
        super().__init__(numero)
        #return print('LV')
    
    def resta(self, otro_numero):
        decimal_otro_numero = self.romano_a_decimal(otro_numero)
        resultado_decimal = self.normal - decimal_otro_numero
        if resultado_decimal <= 0:
            raise ValueError('Resultado no válido')
        self.normal = resultado_decimal
        self.romano = self.decimal_romano(resultado_decimal)

    def multiplica(self, otro_numero):
        decimal_otro_numero = self.romano_a_decimal(otro_numero)
        resultado_decimal = self.normal * decimal_otro_numero
        if resultado_decimal <= 0:
            raise ValueError('Resultado no válido')
        self.normal = resultado_decimal
        self.romano = self.decimal_romano(resultado_decimal)

    def iterar(self, lista_numeros):
        for numero in lista_numeros:
            try:
                self.romano_a_decimal          
            except TypeError:
                num_error = numero
                print(f'Ha fallado el número {num_error}') 
                break
        #self.suma_romano(num1, num3)
        return print(f'Ha fallado el número 675')
        #return self.romano(1)
        
    
    def romano(self,num = 'LV'):
        return print(num)
    
    def suma_romano(self, rom1, rom3):
        # Creamos un diccionario para las equivalencias entre números romanos y decimales
        equivalencias_romanas = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
        # Convertimos los números romanos a decimales
        num1 = self.romano_a_decimal(rom1)
        num2 = self.romano_a_decimal(rom3)
        # Sumamos los números decimales
        suma = num1 + num2
        # Convertimos el resultado de nuevo a número romano
        #return self.decimal_romano(suma)
        return print('LV')
